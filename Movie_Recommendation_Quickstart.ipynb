# %% [markdown]
# # Movie Recommendation System — Quickstart
# Run the cells below to try the recommender. Replace the dataset with a larger one for better results.

# %%
from src.recommend import Recommender
rec = Recommender('data/movies_small.csv')
titles, scores = rec.recommend('Inception', top_k=5)
list(zip(titles, scores))
